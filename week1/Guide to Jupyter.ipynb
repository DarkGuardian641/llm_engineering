# %% [markdown]
# # Jupyter Lab
#
# ## A Quick Start Guide
#
# Welcome to the wonderful world of Jupyter lab!
# This is a Data Science playground where you can easily write code and investigate the results. It's an ideal environment for:
# - Research & Development
# - Prototyping
# - Learning (that's us!)
#
# It's not typically used for shipping production code, and in Week 8 we'll explore the bridge between Jupyter and python code.
#
# A file in Jupyter Lab, like this one, is called a **Notebook**.
#
# A long time ago, Jupyter used to be called "IPython", and so the extensions of notebooks are ".ipynb" which stands for "IPython Notebook".
#
# On the left is a File Browser that lets you navigate around the directories and choose different notebooks. But you probably know that already, or you wouldn't have got here!
#
# The notebook consists of a series of square boxes called "cells". Some of them contain text, like this cell, and some of them contain code, like the cell below.
#
# Click in a cell with code and press `Shift + Return` (or `Shift + Enter`) to run the code and print the output.
#
# Do that now for the cell below this:

# %%
# Click anywhere in this cell and press Shift + Return

2 + 2
# Out:
# 4

# %% [markdown]
# ## Congrats!
#
# Now run the next cell which sets a value, followed by the cells after it to print the value

# %%
# Set a value for a variable

favorite_fruit = "bananas"

# %%
# The result of the last statement is shown after you run it

favorite_fruit
# Out:
# 'bananas'

# %%
# Use the variable

print(f"My favorite fruit is {favorite_fruit}")
# Out:
# My favorite fruit is bananas

# %%
# Now change the variable

favorite_fruit = f"anything but {favorite_fruit}"

# %% [markdown]
# ## Now go back and rerun the cell with the print statement, two cells back
#
# See how it prints something different, even though favorite_fruit was changed further down in the notebook?
#
# The order that code appears in the notebook doesn't matter. What matters is the order that the code is **executed**. There's a python process sitting behind this notebook in which the variables are being changed.
#
# This catches some people out when they first use Jupyter.

# %%
# Then run this cell twice, and see if you understand what's going on

print(f"My favorite fruit is {favorite_fruit}")

favorite_fruit = "apples"
# Out:
# My favorite fruit is anything but bananas

# %% [markdown]
# # Explaining the 'kernel'
#
# Sitting behind this notebook is a Python process which executes each cell when you run it. That Python process is known as the Kernel. Each notebook has its own separate Kernel.
#
# You can go to the Kernel menu and select "Restart Kernel".
#
# If you then try to run the next cell, you'll get an error, because favorite_fruit is no longer defined. You'll need to run the cells from the top of the notebook again. Then the next cell should run fine.

# %%
print(f"My favorite fruit is {favorite_fruit}")
# Out:
# My favorite fruit is apples

# %% [markdown]
# # Adding and moving cells
#
# Click in this cell, then click the \[+\] button in the toolbar above to create a new cell immediately below this one. Copy and paste in the code in the prior cell, then run it! There are also icons in the top right of the selected cell to delete it (bin), duplicate it, and move it up and down.

# %% [markdown]
# # Cell output
#
# When you execute a cell, the standard output and the result of the last statement is written to the area immediately under the code, known as the 'cell output'. When you save a Notebook from the file menu (or command+S), the output is also saved, making it a useful record of what happened.
#
# You can clean this up by going to Edit menu >> Clear Outputs of All Cells, or Kernel menu >> Restart Kernel and Clear Outputs of All Cells.

# %%
spams = ["spam"] * 1000
print(spams)

# Might be worth clearing output after running this!
# Out:
# ['spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', 'spam', ...

# %% [markdown]
# # Using markdown
#
# So what's going on with these areas with writing in them, like this one? Well, there's actually a different kind of cell called a 'Markdown' cell for adding explanations like this. Click the + button to add a cell. Then in the toolbar, click where it says 'Code' and change it to 'Markdown'.
#
# Add some comments using Markdown format, perhaps copying and pasting from here:
#
# ```
# # This is a heading
# ## This is a sub-head
# ### And a sub-sub-head
#
# I like Jupyter Lab because it's
# - Easy
# - Flexible
# - Satisfying
# ```
#
# And to turn this into formatted text simply with Shift+Return in the cell.
# Click in the cell and press the Bin icon if you want to remove it.

# %% [markdown]
# # The exclamation point
#
# There's a super useful feature of jupyter labs; you can type a command with a ! in front of it in a code cell, like:
#
# !pip install \[some_package\]
#
# And it will run it at the command line (as if in Windows Powershell or Mac Terminal) and print the result

# %%
# list the current directory

# !ls
# Out:
# Guide to Jupyter.ipynb
# Intermediate Python.ipynb
# community-contributions
# day1.ipynb
# day2 EXERCISE.ipynb
# day5.ipynb
# diagnostics.py
# solutions
# troubleshooting.ipynb
# week1 EXERCISE.ipynb

# %%
# ping cnn.com - press the stop button in the toolbar when you're bored

# !ping cnn.com
# Out:
# Pinging cnn.com [2a04:4e42:a00::773] with 32 bytes of data:
# Reply from 2a04:4e42:a00::773: time=237ms
# Reply from 2a04:4e42:a00::773: time=254ms
# Reply from 2a04:4e42:a00::773: time=263ms
# Reply from 2a04:4e42:a00::773: time=246ms
#
# Ping statistics for 2a04:4e42:a00::773:
#     Packets: Sent = 4, Received = 4, Lost = 0 (0% loss),
# Approximate round trip times in milli-seconds:
#     Minimum = 237ms, Maximum = 263ms, Average = 250ms

# %%
# This is a useful command that ensures your Anaconda environment 
# is up to date with any new upgrades to packages;
# But it might take a minute and will print a lot to output

# !conda env update -f ../environment.yml
# Out:
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages: ...working...
# libtorch-2.7.1       | 517.6 MB  |            |   0%
#
# pytorch-2.7.1        | 26.6 MB   |            |   0%
#
#
# libgrpc-1.73.1       | 13.9 MB   |            |   0%
#
#
#
# numpy-2.3.1          | 7.6 MB    |            |   0%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    |            |   0%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    |            |   0%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    |            |   0%
#
#
#
#
#
#
#
# libabseil-20250512.1 | 1.5 MB    |            |   0%
#
#
#
#
#
#
#
#
# orc-2.1.3            | 1.1 MB    |            |   0%
#
#
#
#
#
#
#
#
#
# libpulsar-3.7.2      | 888 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# libparquet-20.0.0    | 810 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# grpcio-1.73.1        | 705 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libthrift-0.22.0     | 620 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-6.31.1      | 478 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-acero-20.0. | 446 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-dataset-20. | 432 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarrow-substrait-2 | 346 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libre2-11-2025.06.26 | 259 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re2-2025.06.26       | 212 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libtorch-2.7.1       | 517.6 MB  |            |   0%
#
# pytorch-2.7.1        | 26.6 MB   |            |   0%
#
#
#
# numpy-2.3.1          | 7.6 MB    |            |   0%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    |            |   0%
#
#
#
# numpy-2.3.1          | 7.6 MB    | 1          |   1%
# libtorch-2.7.1       | 517.6 MB  |            |   0%
#
# pytorch-2.7.1        | 26.6 MB   |            |   0%
#
#
# libgrpc-1.73.1       | 13.9 MB   |            |   0%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    |            |   1%
#
# pytorch-2.7.1        | 26.6 MB   | 1          |   1%
#
#
#
# numpy-2.3.1          | 7.6 MB    | 2          |   3%
# libtorch-2.7.1       | 517.6 MB  |            |   0%
#
#
#
# numpy-2.3.1          | 7.6 MB    | 3          |   3%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | 1          |   1%
#
# pytorch-2.7.1        | 26.6 MB   | 1          |   2%
# libtorch-2.7.1       | 517.6 MB  |            |   0%
#
#
#
# numpy-2.3.1          | 7.6 MB    | 5          |   5%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | 2          |   3%
#
# pytorch-2.7.1        | 26.6 MB   | 2          |   2%
# libtorch-2.7.1       | 517.6 MB  |            |   0%
#
#
#
# numpy-2.3.1          | 7.6 MB    | 6          |   7%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | 3          |   3%
#
#
# libgrpc-1.73.1       | 13.9 MB   | 1          |   1%
#
# pytorch-2.7.1        | 26.6 MB   | 2          |   3%
#
#
#
# numpy-2.3.1          | 7.6 MB    | 7          |   8%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | 3          |   4%
#
#
# libgrpc-1.73.1       | 13.9 MB   | 1          |   2%
#
# pytorch-2.7.1        | 26.6 MB   | 2          |   3%
# libtorch-2.7.1       | 517.6 MB  |            |   0%
#
#
#
# numpy-2.3.1          | 7.6 MB    | 9          |  10%
# libtorch-2.7.1       | 517.6 MB  |            |   0%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | 4          |   5%
#
#
# libgrpc-1.73.1       | 13.9 MB   | 2          |   3%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #1         |  11%
#
# pytorch-2.7.1        | 26.6 MB   | 3          |   3%
# libtorch-2.7.1       | 517.6 MB  |            |   0%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | 5          |   6%
#
#
# libgrpc-1.73.1       | 13.9 MB   | 3          |   3%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #2         |  12%
#
# pytorch-2.7.1        | 26.6 MB   | 3          |   4%
# libtorch-2.7.1       | 517.6 MB  |            |   0%
#
#
# libgrpc-1.73.1       | 13.9 MB   | 3          |   4%
#
# pytorch-2.7.1        | 26.6 MB   | 3          |   4%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | 6          |   6%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #3         |  13%
# libtorch-2.7.1       | 517.6 MB  |            |   0%
#
#
# libgrpc-1.73.1       | 13.9 MB   | 4          |   4%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | 7          |   7%
#
# pytorch-2.7.1        | 26.6 MB   | 4          |   4%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #4         |  15%
# libtorch-2.7.1       | 517.6 MB  |            |   0%
#
#
# libgrpc-1.73.1       | 13.9 MB   | 4          |   5%
#
# pytorch-2.7.1        | 26.6 MB   | 4          |   4%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | 7          |   8%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #5         |  16%
#
#
# libgrpc-1.73.1       | 13.9 MB   | 5          |   5%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
# pytorch-2.7.1        | 26.6 MB   | 4          |   5%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | 8          |   8%
#
#
# libgrpc-1.73.1       | 13.9 MB   | 6          |   6%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #6         |  17%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | 6          |   7%
#
# pytorch-2.7.1        | 26.6 MB   | 5          |   5%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | 9          |   9%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #7         |  18%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | 7          |   8%
#
# pytorch-2.7.1        | 26.6 MB   | 5          |   5%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #8         |  19%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | 9          |  10%
#
#
# libgrpc-1.73.1       | 13.9 MB   | 8          |   8%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #9         |  20%
#
# pytorch-2.7.1        | 26.6 MB   | 5          |   6%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #          |  11%
#
#
# libgrpc-1.73.1       | 13.9 MB   | 8          |   9%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ##1        |  21%
#
# pytorch-2.7.1        | 26.6 MB   | 5          |   6%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #1         |  11%
#
#
# libgrpc-1.73.1       | 13.9 MB   | 9          |  10%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ##2        |  22%
#
# pytorch-2.7.1        | 26.6 MB   | 6          |   6%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #          |  10%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #2         |  12%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ##3        |  24%
#
# pytorch-2.7.1        | 26.6 MB   | 6          |   7%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #          |  11%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #2         |  13%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ##4        |  25%
#
# pytorch-2.7.1        | 26.6 MB   | 6          |   7%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #1         |  12%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #3         |  14%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ##5        |  26%
#
# pytorch-2.7.1        | 26.6 MB   | 7          |   7%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #4         |  14%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #2         |  12%
#
# pytorch-2.7.1        | 26.6 MB   | 7          |   7%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ##7        |  27%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #2         |  13%
#
# pytorch-2.7.1        | 26.6 MB   | 7          |   8%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ##8        |  28%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #5         |  16%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #3         |  14%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ##9        |  30%
#
# pytorch-2.7.1        | 26.6 MB   | 7          |   8%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #6         |  17%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #4         |  14%
#
# pytorch-2.7.1        | 26.6 MB   | 8          |   8%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ###        |  31%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #7         |  18%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #4         |  15%
#
# pytorch-2.7.1        | 26.6 MB   | 8          |   9%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ###2       |  32%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #8         |  19%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #5         |  16%
#
# pytorch-2.7.1        | 26.6 MB   | 8          |   9%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ###3       |  33%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #9         |  19%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #6         |  16%
#
# pytorch-2.7.1        | 26.6 MB   | 9          |   9%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ###4       |  35%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ##         |  20%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #6         |  17%
#
# pytorch-2.7.1        | 26.6 MB   | 9          |  10%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ###5       |  36%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ##1        |  21%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #7         |  18%
#
# pytorch-2.7.1        | 26.6 MB   | 9          |  10%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ###7       |  37%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ##2        |  22%
#
# pytorch-2.7.1        | 26.6 MB   | #          |  10%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ###8       |  38%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #8         |  18%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ##3        |  23%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ###9       |  39%
#
# pytorch-2.7.1        | 26.6 MB   | #          |  10%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #8         |  19%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ##4        |  25%
#
# pytorch-2.7.1        | 26.6 MB   | #          |  11%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ####       |  41%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #9         |  19%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ##5        |  26%
#
# pytorch-2.7.1        | 26.6 MB   | #          |  11%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #9         |  20%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ####1      |  42%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ##         |  21%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ####3      |  43%
#
# pytorch-2.7.1        | 26.6 MB   | #1         |  11%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ##7        |  27%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ##1        |  21%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ####4      |  44%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
# pytorch-2.7.1        | 26.6 MB   | #1         |  12%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ##8        |  29%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ##1        |  22%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ####5      |  46%
#
# pytorch-2.7.1        | 26.6 MB   | #1         |  12%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ##2        |  22%
# libtorch-2.7.1       | 517.6 MB  |            |   1%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ####6      |  47%
#
# pytorch-2.7.1        | 26.6 MB   | #2         |  12%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ##9        |  30%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ##2        |  23%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ####8      |  48%
#
# pytorch-2.7.1        | 26.6 MB   | #2         |  12%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ###1       |  31%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ##3        |  23%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ####9      |  49%
#
# pytorch-2.7.1        | 26.6 MB   | #2         |  13%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ###2       |  32%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ##4        |  24%
#
# pytorch-2.7.1        | 26.6 MB   | #3         |  13%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #####      |  50%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ###3       |  34%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ##4        |  25%
#
# pytorch-2.7.1        | 26.6 MB   | #3         |  13%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #####1     |  52%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ##5        |  25%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
# pytorch-2.7.1        | 26.6 MB   | #3         |  14%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ###4       |  35%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #####2     |  53%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ##5        |  26%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
# pytorch-2.7.1        | 26.6 MB   | #3         |  14%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ###5       |  36%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #####4     |  54%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ##6        |  26%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
# pytorch-2.7.1        | 26.6 MB   | #4         |  14%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #####5     |  55%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ###7       |  37%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ##7        |  27%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
# pytorch-2.7.1        | 26.6 MB   | #4         |  15%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ###8       |  38%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #####6     |  57%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ##7        |  28%
#
# pytorch-2.7.1        | 26.6 MB   | #4         |  15%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ###9       |  40%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #####7     |  58%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ##8        |  28%
#
# pytorch-2.7.1        | 26.6 MB   | #5         |  15%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ####       |  41%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #####9     |  59%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ##8        |  29%
#
# pytorch-2.7.1        | 26.6 MB   | #5         |  15%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ####1      |  42%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ######     |  60%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ##9        |  30%
#
# pytorch-2.7.1        | 26.6 MB   | #5         |  16%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ####2      |  43%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ######1    |  62%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ###        |  30%
#
# pytorch-2.7.1        | 26.6 MB   | #6         |  16%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ####3      |  44%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ######2    |  63%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ###        |  31%
#
# pytorch-2.7.1        | 26.6 MB   | #6         |  16%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ####4      |  45%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ######3    |  64%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ###1       |  31%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
# pytorch-2.7.1        | 26.6 MB   | #6         |  17%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ######5    |  65%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ####6      |  46%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ###2       |  32%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
# pytorch-2.7.1        | 26.6 MB   | #6         |  17%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ######6    |  66%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ####7      |  47%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ###2       |  33%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
# pytorch-2.7.1        | 26.6 MB   | #7         |  17%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ######7    |  68%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ####8      |  48%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ###3       |  33%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ######8    |  69%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ####9      |  49%
#
# pytorch-2.7.1        | 26.6 MB   | #7         |  17%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ###4       |  34%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #######    |  70%
#
# pytorch-2.7.1        | 26.6 MB   | #7         |  18%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #####      |  50%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ###4       |  35%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #######1   |  71%
#
# pytorch-2.7.1        | 26.6 MB   | #8         |  18%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #####1     |  51%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ###5       |  35%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #######2   |  73%
#
# pytorch-2.7.1        | 26.6 MB   | #8         |  18%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #####2     |  52%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ###6       |  36%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #######3   |  74%
#
# pytorch-2.7.1        | 26.6 MB   | #8         |  19%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #####3     |  54%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ###6       |  37%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #######5   |  75%
#
# pytorch-2.7.1        | 26.6 MB   | #8         |  19%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #####4     |  55%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ###7       |  37%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #######6   |  76%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
# pytorch-2.7.1        | 26.6 MB   | #9         |  19%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ###8       |  38%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #####5     |  56%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #######7   |  77%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
# pytorch-2.7.1        | 26.6 MB   | #9         |  20%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ###8       |  39%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #####7     |  57%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #######8   |  79%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
# pytorch-2.7.1        | 26.6 MB   | #9         |  20%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ###9       |  39%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #####8     |  58%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #######9   |  80%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
# pytorch-2.7.1        | 26.6 MB   | ##         |  20%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #####9     |  59%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ####       |  40%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ########1  |  81%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ######     |  60%
#
# pytorch-2.7.1        | 26.6 MB   | ##         |  20%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ####       |  41%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ########2  |  82%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
# pytorch-2.7.1        | 26.6 MB   | ##         |  21%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ######1    |  61%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ####1      |  41%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ########3  |  84%
# libtorch-2.7.1       | 517.6 MB  | 1          |   1%
#
# pytorch-2.7.1        | 26.6 MB   | ##1        |  21%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ####2      |  42%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ######2    |  62%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ########4  |  85%
#
# pytorch-2.7.1        | 26.6 MB   | ##1        |  21%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ####2      |  43%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ######3    |  63%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ########6  |  86%
#
# pytorch-2.7.1        | 26.6 MB   | ##1        |  22%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ####3      |  43%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ########7  |  87%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ######4    |  65%
#
# pytorch-2.7.1        | 26.6 MB   | ##1        |  22%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ####4      |  44%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ########8  |  89%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ######5    |  66%
#
# pytorch-2.7.1        | 26.6 MB   | ##2        |  22%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ####4      |  45%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ########9  |  90%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ######6    |  67%
#
# pytorch-2.7.1        | 26.6 MB   | ##2        |  22%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ####5      |  46%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #########  |  91%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ######7    |  68%
#
# pytorch-2.7.1        | 26.6 MB   | ##2        |  23%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ####6      |  46%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #########2 |  92%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ######9    |  69%
#
# pytorch-2.7.1        | 26.6 MB   | ##3        |  23%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ####6      |  47%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #########3 |  93%
#
# pytorch-2.7.1        | 26.6 MB   | ##3        |  23%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #######    |  70%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ####7      |  48%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #########4 |  95%
#
# pytorch-2.7.1        | 26.6 MB   | ##3        |  24%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #######1   |  71%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ####8      |  48%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #########5 |  96%
#
# pytorch-2.7.1        | 26.6 MB   | ##3        |  24%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #######2   |  73%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ####8      |  49%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #########7 |  97%
#
# pytorch-2.7.1        | 26.6 MB   | ##4        |  24%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #######3   |  74%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ####9      |  50%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #########8 |  98%
#
# pytorch-2.7.1        | 26.6 MB   | ##4        |  25%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #######4   |  75%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
#
# numpy-2.3.1          | 7.6 MB    | #########9 | 100%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####      |  50%
#
# pytorch-2.7.1        | 26.6 MB   | ##4        |  25%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ########## | 100%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #######6   |  76%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####      |  51%
#
# pytorch-2.7.1        | 26.6 MB   | ##5        |  25%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    |            |   0%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #######7   |  78%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####1     |  52%
#
# pytorch-2.7.1        | 26.6 MB   | ##5        |  26%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | 1          |   2%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####2     |  52%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #######9   |  79%
#
# pytorch-2.7.1        | 26.6 MB   | ##5        |  26%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | 3          |   4%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####2     |  53%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ########   |  81%
#
# pytorch-2.7.1        | 26.6 MB   | ##6        |  26%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | 5          |   5%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####3     |  53%
#
# pytorch-2.7.1        | 26.6 MB   | ##6        |  26%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | 6          |   7%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ########1  |  82%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####4     |  54%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | 8          |   9%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ########3  |  83%
#
# pytorch-2.7.1        | 26.6 MB   | ##6        |  27%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####4     |  55%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #          |  10%
#
# pytorch-2.7.1        | 26.6 MB   | ##6        |  27%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ########4  |  84%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####5     |  55%
#
# pytorch-2.7.1        | 26.6 MB   | ##7        |  27%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #1         |  12%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ########5  |  86%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####5     |  56%
#
# pytorch-2.7.1        | 26.6 MB   | ##7        |  28%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #3         |  13%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ########6  |  87%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####6     |  56%
#
# pytorch-2.7.1        | 26.6 MB   | ##7        |  28%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ########7  |  88%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #4         |  15%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####7     |  57%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
# pytorch-2.7.1        | 26.6 MB   | ##8        |  28%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ########9  |  89%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #6         |  16%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####7     |  58%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
# pytorch-2.7.1        | 26.6 MB   | ##8        |  28%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #7         |  18%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #########  |  90%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####8     |  58%
#
# pytorch-2.7.1        | 26.6 MB   | ##8        |  29%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####8     |  59%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #########1 |  91%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #9         |  19%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
# pytorch-2.7.1        | 26.6 MB   | ##9        |  29%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####9     |  59%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ##         |  21%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #########2 |  93%
#
# pytorch-2.7.1        | 26.6 MB   | ##9        |  29%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #####9     |  60%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ##2        |  22%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #########3 |  94%
#
# pytorch-2.7.1        | 26.6 MB   | ##9        |  30%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ######     |  61%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ##3        |  24%
# libtorch-2.7.1       | 517.6 MB  | 1          |   2%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #########4 |  95%
#
# pytorch-2.7.1        | 26.6 MB   | ###        |  30%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ######1    |  61%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
# pytorch-2.7.1        | 26.6 MB   | ###        |  30%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ##5        |  25%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #########5 |  96%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ######1    |  62%
#
#
#
# numpy-2.3.1          | 7.6 MB    | ########## | 100%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
# pytorch-2.7.1        | 26.6 MB   | ###        |  31%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #########7 |  97%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ##6        |  27%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ######2    |  62%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
# pytorch-2.7.1        | 26.6 MB   | ###        |  31%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ##8        |  28%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #########8 |  98%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ######2    |  63%
#
# pytorch-2.7.1        | 26.6 MB   | ###1       |  31%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | #########9 |  99%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ##9        |  30%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ######3    |  64%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ########## | 100%
#
# pytorch-2.7.1        | 26.6 MB   | ###1       |  32%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ###1       |  31%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ######4    |  64%
#
# pytorch-2.7.1        | 26.6 MB   | ###2       |  32%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ###2       |  33%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    |            |   0%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ######5    |  65%
#
# pytorch-2.7.1        | 26.6 MB   | ###2       |  32%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ###4       |  34%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | 1          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ######5    |  66%
#
# pytorch-2.7.1        | 26.6 MB   | ###2       |  33%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ###5       |  36%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ######6    |  66%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | 4          |   5%
#
# pytorch-2.7.1        | 26.6 MB   | ###3       |  33%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ###7       |  37%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ######7    |  67%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | 6          |   7%
#
# pytorch-2.7.1        | 26.6 MB   | ###3       |  34%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ###8       |  39%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ######7    |  68%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | 8          |   9%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
# pytorch-2.7.1        | 26.6 MB   | ###3       |  34%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ####       |  40%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ######8    |  68%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #          |  11%
#
#
#
#
# libprotobuf-6.31.1   | 7.3 MB    | ########## | 100%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
# pytorch-2.7.1        | 26.6 MB   | ###4       |  34%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ######9    |  69%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ####1      |  42%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #2         |  13%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
# pytorch-2.7.1        | 26.6 MB   | ###4       |  34%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ####3      |  43%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ######9    |  70%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #4         |  15%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
# pytorch-2.7.1        | 26.6 MB   | ###4       |  35%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ####4      |  45%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #######    |  70%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #6         |  16%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
# pytorch-2.7.1        | 26.6 MB   | ###5       |  35%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ####6      |  46%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #######1   |  71%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #9         |  19%
#
# pytorch-2.7.1        | 26.6 MB   | ###5       |  35%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #######1   |  72%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ####7      |  48%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
# pytorch-2.7.1        | 26.6 MB   | ###5       |  36%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ##1        |  22%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #######2   |  72%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ####9      |  49%
#
# pytorch-2.7.1        | 26.6 MB   | ###6       |  36%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ##3        |  23%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #######3   |  73%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #####      |  51%
#
# pytorch-2.7.1        | 26.6 MB   | ###6       |  36%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ##5        |  25%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #######3   |  74%
#
# pytorch-2.7.1        | 26.6 MB   | ###6       |  37%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #####2     |  52%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ##7        |  27%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #######4   |  74%
#
# pytorch-2.7.1        | 26.6 MB   | ###6       |  37%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #####3     |  54%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ###        |  30%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
# pytorch-2.7.1        | 26.6 MB   | ###7       |  37%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #######5   |  75%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #####5     |  55%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ###2       |  33%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
# pytorch-2.7.1        | 26.6 MB   | ###7       |  38%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #######5   |  76%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #####6     |  57%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ###4       |  35%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #######6   |  76%
#
# pytorch-2.7.1        | 26.6 MB   | ###7       |  38%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #####8     |  58%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ###7       |  37%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #######6   |  77%
#
# pytorch-2.7.1        | 26.6 MB   | ###8       |  38%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #####9     |  60%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #######7   |  77%
#
# pytorch-2.7.1        | 26.6 MB   | ###8       |  39%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ###9       |  39%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ######1    |  61%
# libtorch-2.7.1       | 517.6 MB  | 2          |   2%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #######7   |  78%
#
# pytorch-2.7.1        | 26.6 MB   | ###8       |  39%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ####2      |  42%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ######2    |  63%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #######8   |  79%
#
# pytorch-2.7.1        | 26.6 MB   | ###9       |  39%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ####4      |  44%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ######4    |  64%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #######9   |  79%
#
# pytorch-2.7.1        | 26.6 MB   | ###9       |  40%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ####6      |  47%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ######5    |  66%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #######9   |  80%
#
# pytorch-2.7.1        | 26.6 MB   | ###9       |  40%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ####9      |  49%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########   |  80%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ######7    |  67%
#
# pytorch-2.7.1        | 26.6 MB   | ####       |  40%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #####1     |  51%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########   |  81%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ######8    |  69%
#
# pytorch-2.7.1        | 26.6 MB   | ####       |  40%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #####3     |  54%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########1  |  81%
#
# pytorch-2.7.1        | 26.6 MB   | ####       |  41%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #######    |  70%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #####5     |  56%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########2  |  82%
#
# pytorch-2.7.1        | 26.6 MB   | ####1      |  41%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #######1   |  72%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #####8     |  58%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########2  |  83%
#
# pytorch-2.7.1        | 26.6 MB   | ####1      |  41%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #######3   |  73%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ######     |  61%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########3  |  83%
#
# pytorch-2.7.1        | 26.6 MB   | ####1      |  42%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ######3    |  64%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #######4   |  75%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########3  |  84%
#
# pytorch-2.7.1        | 26.6 MB   | ####1      |  42%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #######5   |  76%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ######5    |  66%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########4  |  84%
#
# pytorch-2.7.1        | 26.6 MB   | ####2      |  42%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #######7   |  77%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ######8    |  69%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########4  |  85%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
# pytorch-2.7.1        | 26.6 MB   | ####2      |  43%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #######8   |  79%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #######1   |  71%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########5  |  86%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
# pytorch-2.7.1        | 26.6 MB   | ####2      |  43%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #######3   |  73%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ########   |  80%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########6  |  86%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
# pytorch-2.7.1        | 26.6 MB   | ####3      |  43%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #######5   |  76%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########6  |  87%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ########1  |  82%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
# pytorch-2.7.1        | 26.6 MB   | ####3      |  43%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #######7   |  78%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########7  |  87%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ########3  |  83%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
# pytorch-2.7.1        | 26.6 MB   | ####3      |  44%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ########   |  80%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########7  |  88%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ########4  |  85%
#
# pytorch-2.7.1        | 26.6 MB   | ####4      |  44%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ########2  |  82%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########8  |  88%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ########6  |  86%
#
# pytorch-2.7.1        | 26.6 MB   | ####4      |  44%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ########4  |  85%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########8  |  89%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ########7  |  88%
#
# pytorch-2.7.1        | 26.6 MB   | ####4      |  45%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ########7  |  87%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########9  |  89%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ########9  |  89%
#
# pytorch-2.7.1        | 26.6 MB   | ####4      |  45%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #########  |  90%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ########9  |  89%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #########  |  91%
#
# pytorch-2.7.1        | 26.6 MB   | ####5      |  45%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #########  |  91%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #########1 |  92%
#
# pytorch-2.7.1        | 26.6 MB   | ####5      |  45%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #########2 |  92%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #########1 |  91%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #########3 |  94%
#
# pytorch-2.7.1        | 26.6 MB   | ####5      |  46%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #########3 |  94%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #########1 |  92%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #########6 |  97%
#
# pytorch-2.7.1        | 26.6 MB   | ####6      |  46%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #########5 |  95%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #########2 |  92%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | #########9 |  99%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ########## | 100%
#
# pytorch-2.7.1        | 26.6 MB   | ####6      |  46%
# libtorch-2.7.1       | 517.6 MB  | 2          |   3%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #########6 |  97%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #########2 |  93%
#
#
#
#
#
#
#
# libabseil-20250512.1 | 1.5 MB    | 1          |   1%
#
# pytorch-2.7.1        | 26.6 MB   | ####6      |  47%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #########3 |  93%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #########8 |  98%
#
#
#
#
#
#
#
# libabseil-20250512.1 | 1.5 MB    | 6          |   6%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
# pytorch-2.7.1        | 26.6 MB   | ####6      |  47%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #########4 |  94%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | #########9 | 100%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ########## | 100%
#
#
#
#
#
#
#
# libabseil-20250512.1 | 1.5 MB    | #1         |  11%
#
# pytorch-2.7.1        | 26.6 MB   | ####7      |  47%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #########4 |  95%
#
#
#
#
#
#
#
#
# orc-2.1.3            | 1.1 MB    | 1          |   1%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
#
#
#
#
#
#
# libabseil-20250512.1 | 1.5 MB    | #6         |  16%
#
# pytorch-2.7.1        | 26.6 MB   | ####7      |  48%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #########5 |  95%
#
#
#
#
#
#
#
#
# orc-2.1.3            | 1.1 MB    | 7          |   7%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
#
#
#
#
#
#
# libabseil-20250512.1 | 1.5 MB    | ##         |  20%
#
# pytorch-2.7.1        | 26.6 MB   | ####7      |  48%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #########6 |  96%
#
#
#
#
#
#
#
#
# orc-2.1.3            | 1.1 MB    | #3         |  13%
#
#
#
#
#
#
#
# libabseil-20250512.1 | 1.5 MB    | ##6        |  26%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
# pytorch-2.7.1        | 26.6 MB   | ####8      |  48%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #########6 |  97%
#
#
#
#
#
#
#
#
# orc-2.1.3            | 1.1 MB    | #9         |  19%
#
# pytorch-2.7.1        | 26.6 MB   | ####8      |  48%
#
#
#
#
#
#
#
# libabseil-20250512.1 | 1.5 MB    | ###1       |  31%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #########7 |  97%
#
#
#
#
#
#
#
#
# orc-2.1.3            | 1.1 MB    | ##6        |  27%
#
# pytorch-2.7.1        | 26.6 MB   | ####8      |  49%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #########8 |  98%
#
#
#
#
#
#
#
#
# orc-2.1.3            | 1.1 MB    | ###2       |  32%
#
#
#
#
#
#
#
# libabseil-20250512.1 | 1.5 MB    | ###6       |  37%
#
# pytorch-2.7.1        | 26.6 MB   | ####9      |  49%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
# orc-2.1.3            | 1.1 MB    | ###9       |  40%
#
#
#
#
#
#
#
# libabseil-20250512.1 | 1.5 MB    | ####2      |  43%
#
# pytorch-2.7.1        | 26.6 MB   | ####9      |  49%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
#
# libgrpc-1.73.1       | 13.9 MB   | #########9 |  99%
#
#
#
#
#
#
#
#
# orc-2.1.3            | 1.1 MB    | ####7      |  47%
#
#
#
#
#
#
# pyarrow-core-20.0.0  | 3.4 MB    | ########## | 100%
#
# pytorch-2.7.1        | 26.6 MB   | ####9      |  50%
#
#
#
#
#
#
#
# libabseil-20250512.1 | 1.5 MB    | ####8      |  49%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
#
#
#
#
#
#
#
# orc-2.1.3            | 1.1 MB    | #####4     |  55%
#
#
#
#
#
# libarrow-20.0.0      | 5.2 MB    | ########## | 100%
#
#
# libgrpc-1.73.1       | 13.9 MB   | ########## | 100%
#
# pytorch-2.7.1        | 26.6 MB   | #####      |  50%
#
#
#
#
#
#
#
# libabseil-20250512.1 | 1.5 MB    | #####4     |  55%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
#
#
#
#
#
#
#
# orc-2.1.3            | 1.1 MB    | ######1    |  62%
#
#
#
#
#
#
#
#
#
# libpulsar-3.7.2      | 888 KB    | 1          |   2%
#
# pytorch-2.7.1        | 26.6 MB   | #####      |  50%
#
#
#
#
#
#
#
# libabseil-20250512.1 | 1.5 MB    | #####9     |  60%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
#
#
#
#
#
#
#
# orc-2.1.3            | 1.1 MB    | ######9    |  69%
#
#
#
#
#
#
#
#
#
# libpulsar-3.7.2      | 888 KB    | #          |  11%
#
# pytorch-2.7.1        | 26.6 MB   | #####      |  51%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
#
#
#
#
#
#
# libabseil-20250512.1 | 1.5 MB    | ######4    |  65%
#
#
#
#
#
#
#
#
# orc-2.1.3            | 1.1 MB    | #######6   |  77%
#
#
#
#
#
#
#
#
#
# libpulsar-3.7.2      | 888 KB    | #9         |  20%
#
# pytorch-2.7.1        | 26.6 MB   | #####1     |  51%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
#
#
#
#
#
#
# libabseil-20250512.1 | 1.5 MB    | ######9    |  70%
#
#
#
#
#
#
#
#
# orc-2.1.3            | 1.1 MB    | ########4  |  84%
#
#
#
#
#
#
#
#
#
# libpulsar-3.7.2      | 888 KB    | ##8        |  29%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
# pytorch-2.7.1        | 26.6 MB   | #####1     |  51%
#
#
#
#
#
#
#
# libabseil-20250512.1 | 1.5 MB    | #######5   |  75%
#
#
#
#
#
#
#
#
#
# libpulsar-3.7.2      | 888 KB    | ###7       |  38%
#
#
#
#
#
#
#
#
# orc-2.1.3            | 1.1 MB    | #########1 |  91%
# libtorch-2.7.1       | 517.6 MB  | 3          |   3%
#
# ...
#
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (1.4.1)
#
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (5.4.0)
#
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (1.22.1)
#
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (1.27.0)
#
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (1.27.0)
#
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (1.27.0)
#
# Requirement already satisfied: pypika>=0.48.9 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (0.48.9)
#
# Requirement already satisfied: overrides>=7.3.1 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (7.7.0)
#
# Requirement already satisfied: importlib-resources in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (6.5.2)
#
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (4.3.0)
#
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (33.1.0)
#
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (5.1.0)
#
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (4.24.0)
#
# Requirement already satisfied: six>=1.5 in c:\users\athar\appdata\roaming\python\python311\site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (1.17.0)
#
# Requirement already satisfied: backoff>=1.10.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (2.2.1)
#
# Requirement already satisfied: pyproject_hooks in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from build>=1.0.3->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (1.2.0)
#
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (2025.4.1)
#
# Requirement already satisfied: referencing>=0.28.4 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (0.36.2)
#
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (0.26.0)
#
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (1.8.0)
#
# Requirement already satisfied: requests-oauthlib in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (2.0.0)
#
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (3.3.1)
#
# Requirement already satisfied: durationpy>=0.7 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (0.10)
#
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from langsmith>=0.1.17->langchain->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 16)) (1.0.0)
#
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from langsmith>=0.1.17->langchain->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 16)) (0.23.0)
#
# Requirement already satisfied: coloredlogs in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (15.0.1)
#
# Requirement already satisfied: flatbuffers in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (25.2.10)
#
# Requirement already satisfied: sympy in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (1.14.0)
#
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (1.2.18)
#
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (8.4.0)
#
# Requirement already satisfied: zipp>=0.5 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (3.23.0)
#
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (1.17.2)
#
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (1.27.0)
#
# Requirement already satisfied: opentelemetry-proto==1.27.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (1.27.0)
#
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (0.48b0)
#
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 9)) (3.0.0)
#
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 9)) (2.19.1)
#
# Requirement already satisfied: mdurl~=0.1 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 9)) (0.1.2)
#
# Requirement already satisfied: networkx in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from torch>=1.11.0->sentence-transformers->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 4)) (3.5)
#
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (1.3.0)
#
# Requirement already satisfied: httptools>=0.6.3 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (0.6.4)
#
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (10.0)
#
# Requirement already satisfied: pyreadline3 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 20)) (3.5.4)
#
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from google-api-python-client->google-generativeai->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 8)) (0.22.0)
#
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from google-api-python-client->google-generativeai->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 8)) (0.2.0)
#
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from google-api-python-client->google-generativeai->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 8)) (4.2.0)
#
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 8)) (3.2.3)
#
# Requirement already satisfied: joblib>=1.2.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from scikit-learn->sentence-transformers->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 4)) (1.5.1)
#
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\athar\anaconda3\envs\llms\lib\site-packages (from scikit-learn->sentence-transformers->-r c:\Visual Studio Code\llm_engineering\condaenv.3iyd78c6.requirements.txt (line 4)) (3.6.0)
#
# Downloading openai-1.97.0-py3-none-any.whl (764 kB)
#
#    ---------------------------------------- 0.0/765.0 kB ? eta -:--:--
#    ---------------------------------------- 765.0/765.0 kB 6.4 MB/s eta 0:00:00
#
# Downloading langchain_core-0.3.69-py3-none-any.whl (441 kB)
#
# Installing collected packages: openai, langchain-core
#
#
#   Attempting uninstall: openai
#
#
#     Found existing installation: openai 1.95.1
#
#
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#     Uninstalling openai-1.95.1:
#
#    ---------------------------------------- 0/2 [openai]
#       Successfully uninstalled openai-1.95.1
#
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#   Attempting uninstall: langchain-core
#
#    ---------------------------------------- 0/2 [openai]
#     Found existing installation: langchain-core 0.3.68
#
#    ---------------------------------------- 0/2 [openai]
#     Uninstalling langchain-core-0.3.68:
#
#    ---------------------------------------- 0/2 [openai]
#       Successfully uninstalled langchain-core-0.3.68
#
#    ---------------------------------------- 0/2 [openai]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    ---------------------------------------- 2/2 [langchain-core]
#
#
# Successfully installed langchain-core-0.3.69 openai-1.97.0
#
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate llms
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
# C:\Users\athar\anaconda3\Lib\argparse.py:2005: FutureWarning: `remote_definition` is deprecated and will be removed in 25.9. Use `conda env create --file=URL` instead.
#   action(self, namespace, argument_values, option_string)

# %% [markdown]
# # Minor things we encounter on the course
#
# This isn't necessarily a feature of Jupyter, but it's a nice package to know about that is useful in Jupyter Labs, and I use it in the course.
#
# The package `tqdm` will print a nice progress bar if you wrap any iterable.

# %%
# Here's some code with no progress bar
# It will take 10 seconds while you wonder what's happpening..

import time

spams = ["spam"] * 1000

for spam in spams:
    time.sleep(0.01)

# %%
# And now, with a nice little progress bar:

import time
from tqdm import tqdm

spams = ["spam"] * 1000

for spam in tqdm(spams):
    time.sleep(0.01)
# Out:
# 100%|██████████| 1000/1000 [00:10<00:00, 95.99it/s]

# %%
# On a different topic, here's a useful way to print output in markdown

from IPython.display import Markdown, display

display(Markdown("# This is a big heading!\n\n- And this is a bullet-point\n- So is this\n- Me, too!"))
# Out:
# # This is a big heading!
#
# - And this is a bullet-point
# - So is this
# - Me, too!

# %% [markdown]
# # That's it! You're up to speed on Jupyter Lab.
#
# ## Want to be even more advanced?
#
# If you want to become a pro at Jupyter Lab, you can read their tutorial [here](https://jupyterlab.readthedocs.io/en/latest/). But this isn't required for our course; just a good technique for hitting Shift + Return and enjoying the result!
